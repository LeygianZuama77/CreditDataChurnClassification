# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Extract Data

# %%
df = pd.read_csv('Credit Card Churn - Dataset.csv')

# %% [markdown]
# # 2. EDA

# %% [markdown]
# Menampilkan isi Data dan Fitur

# %%
df.head()
# Out:
#    client_id  label  usia gender  jumlah_tanggungan  pendidikan status_nikah  \
# 0  719455083      0    48      F                  3  Uneducated       Single
# 1  773503308      0    59      M                  1  Uneducated       Single
# 2  715452408      0    37      F                  2    Graduate     Divorced
# 3  711264033      0    47      M                  3   Doctorate     Divorced
# 4  718943508      0    42      M                  3     Unknown       Single
#
#   penghasilan_tahunan tipe_kartu_kredit  lama_nasabah  ...  bulan_nonactive  \
# 0      Less than $40K              Blue            39  ...                3
# 1      Less than $40K              Blue            53  ...                5
# 2      Less than $40K              Blue            36  ...                3
# 3         $40K - $60K              Blue            36  ...                2
# 4        $80K - $120K              Blue            33  ...                3
#
# ...

# %% [markdown]
# Menampilkan Informasi Fitur, seperti tipe fitur tersebut dan juga Mencari jenis data ketegorikal

# %% [markdown]
# 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   client_id                     5000 non-null   int64
#  1   label                         5000 non-null   int64
#  2   usia                          5000 non-null   int64
#  3   gender                        5000 non-null   object
#  4   jumlah_tanggungan             5000 non-null   int64
#  5   pendidikan                    5000 non-null   object
#  6   status_nikah                  5000 non-null   object
#  7   penghasilan_tahunan           5000 non-null   object
#  8   tipe_kartu_kredit             5000 non-null   object
#  9   lama_nasabah                  5000 non-null   int64
#  10  jumlah_produk                 5000 non-null   int64
#  11  bulan_nonactive               5000 non-null   int64
# ...

# %% [markdown]
# 2

# %%
for i in (df):
    print(f'feature {i} :{len(df[i].unique())}')
# Out:
# feature client_id :5000
# feature label :2
# feature usia :45
# feature gender :2
# feature jumlah_tanggungan :6
# feature pendidikan :7
# feature status_nikah :4
# feature penghasilan_tahunan :6
# feature tipe_kartu_kredit :4
# feature lama_nasabah :44
# feature jumlah_produk :6
# feature bulan_nonactive :7
# feature jumlah_kontak :7
# feature total_limit_kredit :3580
# feature total_limit_kredit_dipakai :1659
# feature sisa_limit_kredit :3911
# feature rasio_transaksi_Q4_Q1  :964
# feature total_transaksi :3366
# feature jumlah_transaksi :121
# feature rasio_jumlah_transaksi_Q4_Q1 :734
# feature rasio_pemakaian :896

# %% [markdown]
# Mencari Data yang Outlier

# %%
df.describe()
# Out:
#           client_id        label        usia  jumlah_tanggungan  lama_nasabah  \
# count  5.000000e+03  5000.000000  5000.00000         5000.00000   5000.000000
# mean   7.390590e+08     0.160000    46.38880            2.36100     35.913000
# std    3.679612e+07     0.366643     8.03182            1.31203      7.922751
# min    7.080846e+08     0.000000    26.00000            0.00000     13.000000
# 25%    7.130287e+08     0.000000    41.00000            1.00000     31.000000
# 50%    7.179772e+08     0.000000    46.00000            2.00000     36.000000
# 75%    7.728630e+08     0.000000    52.00000            3.00000     40.000000
# max    8.282989e+08     1.000000    73.00000            5.00000     56.000000
#
#        jumlah_produk  bulan_nonactive  jumlah_kontak  total_limit_kredit  \
# count     5000.00000      5000.000000    5000.000000         5000.000000
# mean         3.83380         2.335400       2.464800         8637.409280
# ...

# %%
sns.countplot(data=df,x='label')
df.label.value_counts()
# Out:
# label
# 0    4200
# 1     800
# Name: count, dtype: int64

# %% [markdown]
# Status Nikah

# %%
sns.countplot(data=df, x='label', hue='status_nikah')
plt.show()

# %% [markdown]
# Gender

# %%
sns.countplot(data=df, x='label', hue='gender')
plt.show()

# %% [markdown]
# Pendidikan

# %%
sns.countplot(data=df, x='label', hue='pendidikan')
plt.show()

# %%
sns.displot(data=df,x='pendidikan', hue='label')
plt.xlim([0,7])
plt.ylim([0,1500])
plt.show()

# %% [markdown]
# Tipe Credit Card

# %%
sns.countplot(data=df, x='label', hue='tipe_kartu_kredit')
plt.show()

# %% [markdown]
# penghasilan_tahunan

# %%
sns.countplot(data=df, x='label', hue='penghasilan_tahunan')
plt.show()

# %%
sns.displot(data=df,x='sisa_limit_kredit', hue='label')
plt.xlim([0,34516])
plt.ylim([0,2000])
plt.show()

# %%
sns.displot(data=df,x='jumlah_transaksi', hue='label')
plt.xlim([0,135])
plt.ylim([0,455])
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr().round(2)

# Plot the heatmap
plt.figure(figsize=(20, 12))
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix", size=20)
plt.show()

# %%
df.isna().sum()
# Out:
# client_id                       0
# label                           0
# usia                            0
# gender                          0
# jumlah_tanggungan               0
# pendidikan                      0
# status_nikah                    0
# penghasilan_tahunan             0
# tipe_kartu_kredit               0
# lama_nasabah                    0
# jumlah_produk                   0
# bulan_nonactive                 0
# jumlah_kontak                   0
# total_limit_kredit              0
# total_limit_kredit_dipakai      0
# sisa_limit_kredit               0
# rasio_transaksi_Q4_Q1           0
# total_transaksi                 0
# jumlah_transaksi                0
# rasio_jumlah_transaksi_Q4_Q1    0
# rasio_pemakaian                 0
# dtype: int64

# %%
df.describe()
# Out:
#           client_id        label        usia  jumlah_tanggungan  lama_nasabah  \
# count  5.000000e+03  5000.000000  5000.00000         5000.00000   5000.000000
# mean   7.390590e+08     0.160000    46.38880            2.36100     35.913000
# std    3.679612e+07     0.366643     8.03182            1.31203      7.922751
# min    7.080846e+08     0.000000    26.00000            0.00000     13.000000
# 25%    7.130287e+08     0.000000    41.00000            1.00000     31.000000
# 50%    7.179772e+08     0.000000    46.00000            2.00000     36.000000
# 75%    7.728630e+08     0.000000    52.00000            3.00000     40.000000
# max    8.282989e+08     1.000000    73.00000            5.00000     56.000000
#
#        jumlah_produk  bulan_nonactive  jumlah_kontak  total_limit_kredit  \
# count     5000.00000      5000.000000    5000.000000         5000.000000
# mean         3.83380         2.335400       2.464800         8637.409280
# ...

# %%
df.head()
# Out:
#    client_id  label  usia gender  jumlah_tanggungan  pendidikan status_nikah  \
# 0  719455083      0    48      F                  3  Uneducated       Single
# 1  773503308      0    59      M                  1  Uneducated       Single
# 2  715452408      0    37      F                  2    Graduate     Divorced
# 3  711264033      0    47      M                  3   Doctorate     Divorced
# 4  718943508      0    42      M                  3     Unknown       Single
#
#   penghasilan_tahunan tipe_kartu_kredit  lama_nasabah  ...  bulan_nonactive  \
# 0      Less than $40K              Blue            39  ...                3
# 1      Less than $40K              Blue            53  ...                5
# 2      Less than $40K              Blue            36  ...                3
# 3         $40K - $60K              Blue            36  ...                2
# 4        $80K - $120K              Blue            33  ...                3
#
# ...

# %%
dropped_columns = ['client_id','gender','status_nikah','pendidikan']
df = df.drop(columns=dropped_columns)

# %%
df.head()
# Out:
#    label  usia  jumlah_tanggungan penghasilan_tahunan tipe_kartu_kredit  \
# 0      0    48                  3      Less than $40K              Blue
# 1      0    59                  1      Less than $40K              Blue
# 2      0    37                  2      Less than $40K              Blue
# 3      0    47                  3         $40K - $60K              Blue
# 4      0    42                  3        $80K - $120K              Blue
#
#    lama_nasabah  jumlah_produk  bulan_nonactive  jumlah_kontak  \
# 0            39              4                3              4
# 1            53              5                5              4
# 2            36              4                3              3
# 3            36              4                2              3
# 4            33              3                3              2
#
#    total_limit_kredit  total_limit_kredit_dipakai  sisa_limit_kredit  \
# 0              2991.0                        1508             1483.0
# ...

# %%
age_binning  = [21,44,60,100]
age_category = ['Dewasa','PraLanjutUsia','Lansia']

df['age_category'] = pd.cut(df['usia'],bins=age_binning,labels=age_category)

# %%
df
# Out:
#       label  usia  jumlah_tanggungan penghasilan_tahunan tipe_kartu_kredit  \
# 0         0    48                  3      Less than $40K              Blue
# 1         0    59                  1      Less than $40K              Blue
# 2         0    37                  2      Less than $40K              Blue
# 3         0    47                  3         $40K - $60K              Blue
# 4         0    42                  3        $80K - $120K              Blue
# ...     ...   ...                ...                 ...               ...
# 4995      0    47                  3         $40K - $60K              Blue
# 4996      1    40                  2         $60K - $80K              Blue
# 4997      1    51                  0             Unknown              Blue
# 4998      0    26                  0         $40K - $60K              Blue
# 4999      1    52                  0      Less than $40K              Blue
#
#       lama_nasabah  jumlah_produk  bulan_nonactive  jumlah_kontak  \
# ...

# %%
jumlah= df.isna().sum()

# %%
jumlah
# Out:
# label                           0
# usia                            0
# jumlah_tanggungan               0
# penghasilan_tahunan             0
# tipe_kartu_kredit               0
# lama_nasabah                    0
# jumlah_produk                   0
# bulan_nonactive                 0
# jumlah_kontak                   0
# total_limit_kredit              0
# total_limit_kredit_dipakai      0
# sisa_limit_kredit               0
# rasio_transaksi_Q4_Q1           0
# total_transaksi                 0
# jumlah_transaksi                0
# rasio_jumlah_transaksi_Q4_Q1    0
# rasio_pemakaian                 0
# age_category                    0
# dtype: int64

# %% [markdown]
# # ENCODE

# %%
df = pd.get_dummies(df, columns = ['penghasilan_tahunan','tipe_kartu_kredit'],dtype='int')
df
# Out:
#       label  usia  jumlah_tanggungan  lama_nasabah  jumlah_produk  \
# 0         0    48                  3            39              4
# 1         0    59                  1            53              5
# 2         0    37                  2            36              4
# 3         0    47                  3            36              4
# 4         0    42                  3            33              3
# ...     ...   ...                ...           ...            ...
# 4995      0    47                  3            36              3
# 4996      1    40                  2            20              4
# 4997      1    51                  0            42              1
# 4998      0    26                  0            18              4
# 4999      1    52                  0            36              4
#
#       bulan_nonactive  jumlah_kontak  total_limit_kredit  \
# 0                   3              4              2991.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   label                               5000 non-null   int64
#  1   usia                                5000 non-null   int64
#  2   jumlah_tanggungan                   5000 non-null   int64
#  3   lama_nasabah                        5000 non-null   int64
#  4   jumlah_produk                       5000 non-null   int64
#  5   bulan_nonactive                     5000 non-null   int64
#  6   jumlah_kontak                       5000 non-null   int64
#  7   total_limit_kredit                  5000 non-null   float64
#  8   total_limit_kredit_dipakai          5000 non-null   int64
#  9   sisa_limit_kredit                   5000 non-null   float64
#  10  rasio_transaksi_Q4_Q1               5000 non-null   float64
# ...

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns=['label'])
y = df['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)

# %%
y_train.value_counts(normalize=True)
# Out:
# label
# 0    0.84
# 1    0.16
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# label
# 0    0.84
# 1    0.16
# Name: proportion, dtype: float64

# %% [markdown]
# # Balancing

# %%
from imblearn.over_sampling import RandomOverSampler,SMOTENC

# %%
for i in (df):
    print(f'feature {i} :{len(df[i].unique())}')
# Out:
# feature label :2
# feature usia :45
# feature jumlah_tanggungan :6
# feature lama_nasabah :44
# feature jumlah_produk :6
# feature bulan_nonactive :7
# feature jumlah_kontak :7
# feature total_limit_kredit :3580
# feature total_limit_kredit_dipakai :1659
# feature sisa_limit_kredit :3911
# feature rasio_transaksi_Q4_Q1  :964
# feature total_transaksi :3366
# feature jumlah_transaksi :121
# feature rasio_jumlah_transaksi_Q4_Q1 :734
# feature rasio_pemakaian :896
# feature age_category :3
# feature penghasilan_tahunan_$120K + :2
# feature penghasilan_tahunan_$40K - $60K :2
# feature penghasilan_tahunan_$60K - $80K :2
# feature penghasilan_tahunan_$80K - $120K :2
# feature penghasilan_tahunan_Less than $40K :2
# feature penghasilan_tahunan_Unknown :2
# feature tipe_kartu_kredit_Blue :2
# feature tipe_kartu_kredit_Gold :2
# feature tipe_kartu_kredit_Platinum :2
# feature tipe_kartu_kredit_Silver :2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   label                               5000 non-null   int64
#  1   usia                                5000 non-null   int64
#  2   jumlah_tanggungan                   5000 non-null   int64
#  3   lama_nasabah                        5000 non-null   int64
#  4   jumlah_produk                       5000 non-null   int64
#  5   bulan_nonactive                     5000 non-null   int64
#  6   jumlah_kontak                       5000 non-null   int64
#  7   total_limit_kredit                  5000 non-null   float64
#  8   total_limit_kredit_dipakai          5000 non-null   int64
#  9   sisa_limit_kredit                   5000 non-null   float64
#  10  rasio_transaksi_Q4_Q1               5000 non-null   float64
# ...

# %%
from imblearn.over_sampling import SMOTENC

# Assuming x_train and y_train are your training data
oversampler = SMOTENC(categorical_features='auto', sampling_strategy='auto', random_state=42)
X_train_smotenc, y_train_smotenc = oversampler.fit_resample(x_train, y_train)

# %%
# Visualisai Hasil SMOTENC
plt.figure(figsize=(12,5))
plt.subplot(121)
y_train.value_counts().plot(kind='bar',color=['g','r'])
plt.title("Data Before OverSampling");
plt.subplot(122)
y_train_smotenc.value_counts().plot(kind='bar',color=['g','r'])
plt.title("Data After OverSampling");

# %%
from collections import Counter
count_y_over = Counter(y_train_smotenc)
print(count_y_over)
# Out:
# Counter({1: 3360, 0: 3360})

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# ALAT UNTUK IMPUTASI
from sklearn.impute import SimpleImputer

from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

# Call Model
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier as ada
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier as rforest
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import AdaBoostClassifier as ada
from sklearn.model_selection import GridSearchCV

# Define the numerical preprocessor
num_preprocessor = Pipeline([
    ("num_imputer", SimpleImputer(strategy='mean')),
    ("num_scaler", MinMaxScaler()),
])
cat_preprocessor = Pipeline([("cat_imputer",SimpleImputer(strategy='most_frequent')),
                             ("cat_encoder",OneHotEncoder())])
# Define the numerical columns
num_columns = [
    'usia','jumlah_tanggungan', 'lama_nasabah', 'jumlah_produk', 'bulan_nonactive', 'jumlah_kontak',
    'total_limit_kredit', 'total_limit_kredit_dipakai', 'sisa_limit_kredit', 'rasio_transaksi_Q4_Q1 ',
    'total_transaksi', 'jumlah_transaksi', 'rasio_jumlah_transaksi_Q4_Q1', 'rasio_pemakaian',
    'penghasilan_tahunan_$120K +', 'penghasilan_tahunan_$40K - $60K', 'penghasilan_tahunan_$60K - $80K',
    'penghasilan_tahunan_$80K - $120K', 'penghasilan_tahunan_Less than $40K', 'penghasilan_tahunan_Unknown',
    'tipe_kartu_kredit_Blue', 'tipe_kartu_kredit_Gold', 'tipe_kartu_kredit_Platinum', 'tipe_kartu_kredit_Silver'
]
cat_columns = ['age_category']

# Define the ColumnTransformer with only the numerical pipeline
preprocessor = ColumnTransformer([("num_pipeline",num_preprocessor,num_columns),
                                  ("cat_pipeline",cat_preprocessor,cat_columns)])

# Complete pipeline

adaboost = Pipeline([
    ("preprocess", preprocessor),
    ("model", ada())
])

xgb = Pipeline([
    ("preprocess", preprocessor),
    ("model", XGBClassifier())
])

DecisionTree = Pipeline([
    ("preprocess", preprocessor),
    ("model", DecisionTreeClassifier())
])

catboost = Pipeline([
    ("preprocess", preprocessor),
    ("model", CatBoostClassifier())
])

randomForest =Pipeline([
    ("preprocess", preprocessor),
    ("model", rforest())
])

knn = Pipeline([
    ("preprocess", preprocessor),
    ("model", KNeighborsClassifier())
])

LogistRegress = Pipeline([
    ("preprocess", preprocessor),
    ("model", LogisticRegression())
])

# %% [markdown]
# # ADABOOST Klasifikasi

# %%
from sklearn import set_config
set_config(display=None)

adaboost
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
adaboost.get_params()

# %%
# Import Library GSCV
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Imbalance

# %%
adaboost_gscv = GridSearchCV(estimator=adaboost,
                          param_grid={
                                'preprocess__num_pipeline__num_imputer__strategy': ['mean', 'median'],
    'preprocess__cat_pipeline__cat_imputer__strategy': ['most_frequent', 'constant'],
    'model__n_estimators': [50, 100, 200],
    'model__learning_rate': [0.01, 0.1, 1.0]
                          },
                          cv=5,
                          verbose=1)

adaboost_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('num_imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('num_scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['usia',
#                                                                           'jumlah_tanggungan',
#                                                                           'lama_nasabah',
# ...

# %%
adaboost_gscv_balanced = adaboost_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
from sklearn.metrics import classification_report

def model_performance(model):
    y_train_pred = model.predict(x_train)
    y_test_pred  = model.predict(x_test)
    print('Model Performance on Data Training')
    print(classification_report(y_train,y_train_pred))

    print('Model Performance on Data Testing')
    print(classification_report(y_test,y_test_pred))

# %%
def classification_model_performance(model,X,y,label="Training"):
    print("Model Performance in Data",label)
    y_pred = model.predict(X)
    print(classification_report(y,y_pred))

# %% [markdown]
# Unbalance

# %%
model_performance(adaboost_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3360
#            1       0.89      0.91      0.90       640
#
#     accuracy                           0.97      4000
#    macro avg       0.93      0.95      0.94      4000
# weighted avg       0.97      0.97      0.97      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       840
#            1       0.82      0.89      0.85       160
#
#     accuracy                           0.95      1000
#    macro avg       0.90      0.93      0.91      1000
# weighted avg       0.95      0.95      0.95      1000

# %% [markdown]
# Balancing

# %%
classification_model_performance(adaboost_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(adaboost_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3360
#            1       0.98      0.98      0.98      3360
#
#     accuracy                           0.98      6720
#    macro avg       0.98      0.98      0.98      6720
# weighted avg       0.98      0.98      0.98      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       840
#            1       0.82      0.89      0.85       160
#
#     accuracy                           0.95      1000
#    macro avg       0.90      0.93      0.91      1000
# weighted avg       0.95      0.95      0.95      1000

# %% [markdown]
# # XGBOOST

# %%
from sklearn import set_config
set_config(display=None)

xgb
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
xgb.get_params()

# %%
xgb_gscv = GridSearchCV(estimator=xgb,
                          param_grid = {
                                            'model__n_estimators': [50, 100, 200],
                                            'model__max_depth': [200, 350, 500],
                                            'model__min_child_weight': [20, 40, 80]
                                        },
                          cv=5,
                          verbose=1)

xgb_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('num_imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('num_scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['usia',
#                                                                           'jumlah_tanggungan',
#                                                                           'lama_nasabah',
# ...

# %%
xgb_gscv_balanced = xgb_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# {'model__max_depth': 200,
#  'model__min_child_weight': 20,
#  'model__n_estimators': 200}

# %% [markdown]
# Unbalance

# %%
model_performance(xgb_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      3360
#            1       0.97      0.99      0.98       640
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.99      0.99      4000
# weighted avg       0.99      0.99      0.99      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       840
#            1       0.86      0.91      0.88       160
#
#     accuracy                           0.96      1000
#    macro avg       0.92      0.94      0.93      1000
# weighted avg       0.96      0.96      0.96      1000

# %% [markdown]
# Balance

# %%
classification_model_performance(xgb_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(xgb_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      3360
#            1       0.99      1.00      1.00      3360
#
#     accuracy                           1.00      6720
#    macro avg       1.00      1.00      1.00      6720
# weighted avg       1.00      1.00      1.00      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       840
#            1       0.86      0.91      0.88       160
#
#     accuracy                           0.96      1000
#    macro avg       0.92      0.94      0.93      1000
# weighted avg       0.96      0.96      0.96      1000

# %% [markdown]
# # Decision Tree

# %%
from sklearn import set_config
set_config(display=None)

DecisionTree
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
DecisionTree.get_params()

# %%
Decision3_gscv = GridSearchCV(estimator=DecisionTree,
                          param_grid = {
                                            'model__min_samples_leaf': [30, 75, 95],
                                            'model__min_samples_split': [2, 8, 16],
                                           'model__criterion': ['entropy']
                                        },
                          cv=5,
                          verbose=1)

Decision3_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('num_imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('num_scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['usia',
#                                                                           'jumlah_tanggungan',
#                                                                           'lama_nasabah',
# ...

# %%
Decision3_gscv_balanced = Decision3_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits

# %% [markdown]
# Unbalance

# %%
model_performance(Decision3_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96      3360
#            1       0.72      0.92      0.81       640
#
#     accuracy                           0.93      4000
#    macro avg       0.85      0.93      0.88      4000
# weighted avg       0.94      0.93      0.93      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       840
#            1       0.67      0.90      0.77       160
#
#     accuracy                           0.91      1000
#    macro avg       0.83      0.91      0.86      1000
# weighted avg       0.93      0.91      0.92      1000

# %% [markdown]
# Balance

# %%
classification_model_performance(Decision3_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(Decision3_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3360
#            1       0.93      0.95      0.94      3360
#
#     accuracy                           0.94      6720
#    macro avg       0.94      0.94      0.94      6720
# weighted avg       0.94      0.94      0.94      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       840
#            1       0.67      0.90      0.77       160
#
#     accuracy                           0.91      1000
#    macro avg       0.83      0.91      0.86      1000
# weighted avg       0.93      0.91      0.92      1000

# %% [markdown]
# # CatBoost

# %%
from sklearn import set_config
set_config(display=None)

catboost
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
catboost.get_params()

# %%
catboost_gscv = GridSearchCV(estimator=catboost,
                          param_grid = {
                                            'preprocess__cat_pipeline__cat_imputer__strategy': ['most_frequent'],
                                            'preprocess__cat_pipeline__cat_encoder__categories': ['auto'],
                                        },
                          cv=5,
                          verbose=1)

catboost_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Learning rate set to 0.016929
# 0:	learn: 0.6736220	total: 4.81ms	remaining: 4.8s
# 1:	learn: 0.6517769	total: 9.83ms	remaining: 4.9s
# 2:	learn: 0.6305743	total: 14.6ms	remaining: 4.87s
# 3:	learn: 0.6112125	total: 19.1ms	remaining: 4.75s
# 4:	learn: 0.5956177	total: 23.1ms	remaining: 4.59s
# 5:	learn: 0.5792367	total: 27.6ms	remaining: 4.58s
# 6:	learn: 0.5621822	total: 32.2ms	remaining: 4.56s
# 7:	learn: 0.5466404	total: 36.5ms	remaining: 4.52s
# 8:	learn: 0.5316531	total: 40.9ms	remaining: 4.5s
# 9:	learn: 0.5181455	total: 46.5ms	remaining: 4.6s
# 10:	learn: 0.5059664	total: 52.3ms	remaining: 4.7s
# 11:	learn: 0.4908393	total: 58.3ms	remaining: 4.8s
# 12:	learn: 0.4790945	total: 65ms	remaining: 4.94s
# 13:	learn: 0.4669838	total: 70.7ms	remaining: 4.98s
# 14:	learn: 0.4552522	total: 77.4ms	remaining: 5.08s
# 15:	learn: 0.4436810	total: 83.5ms	remaining: 5.14s
# 16:	learn: 0.4335586	total: 90ms	remaining: 5.2s
# ...

# %%
catboost_gscv_balanced = catboost_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Learning rate set to 0.021127
# 0:	learn: 0.6651768	total: 5.96ms	remaining: 5.95s
# 1:	learn: 0.6369674	total: 12ms	remaining: 5.98s
# 2:	learn: 0.6166222	total: 17.4ms	remaining: 5.79s
# 3:	learn: 0.5948647	total: 23ms	remaining: 5.72s
# 4:	learn: 0.5740400	total: 30.3ms	remaining: 6.03s
# 5:	learn: 0.5563849	total: 36.6ms	remaining: 6.06s
# 6:	learn: 0.5367251	total: 43.1ms	remaining: 6.12s
# 7:	learn: 0.5198959	total: 51.6ms	remaining: 6.39s
# 8:	learn: 0.5012459	total: 59.2ms	remaining: 6.52s
# 9:	learn: 0.4847635	total: 66.5ms	remaining: 6.58s
# 10:	learn: 0.4713769	total: 74.3ms	remaining: 6.68s
# 11:	learn: 0.4613731	total: 81.4ms	remaining: 6.7s
# 12:	learn: 0.4482674	total: 88.8ms	remaining: 6.74s
# 13:	learn: 0.4361154	total: 96ms	remaining: 6.76s
# 14:	learn: 0.4239516	total: 103ms	remaining: 6.77s
# 15:	learn: 0.4121057	total: 112ms	remaining: 6.9s
# 16:	learn: 0.4033477	total: 121ms	remaining: 7.02s
# ...

# %% [markdown]
# UNBALANCE

# %%
model_performance(catboost_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       0.99      1.00      0.99       640
#
#     accuracy                           1.00      4000
#    macro avg       0.99      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       840
#            1       0.89      0.91      0.90       160
#
#     accuracy                           0.97      1000
#    macro avg       0.94      0.95      0.94      1000
# weighted avg       0.97      0.97      0.97      1000

# %% [markdown]
# BALANCE

# %%
classification_model_performance(catboost_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(catboost_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       1.00      1.00      1.00      3360
#
#     accuracy                           1.00      6720
#    macro avg       1.00      1.00      1.00      6720
# weighted avg       1.00      1.00      1.00      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       840
#            1       0.89      0.91      0.90       160
#
#     accuracy                           0.97      1000
#    macro avg       0.94      0.95      0.94      1000
# weighted avg       0.97      0.97      0.97      1000

# %% [markdown]
# # RandomForest

# %%
from sklearn import set_config
set_config(display=None)

randomForest
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
randomForest.get_params()

# %%
randomForest_gscv = GridSearchCV(estimator=randomForest,
                          param_grid={
                                'model__max_depth': [350,500,1000],
                                'model__min_samples_leaf': [2,4,8],
                                'model__class_weight': ['balanced'],
                          },
                          cv=5,
                          verbose=1)

randomForest_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('num_imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('num_scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['usia',
#                                                                           'jumlah_tanggungan',
#                                                                           'lama_nasabah',
# ...

# %%
randomForest_gscv_balanced = randomForest_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits

# %% [markdown]
# UNBALANCE

# %%
model_performance(randomForest_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       0.98      1.00      0.99       640
#
#     accuracy                           1.00      4000
#    macro avg       0.99      1.00      0.99      4000
# weighted avg       1.00      1.00      1.00      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       840
#            1       0.84      0.89      0.86       160
#
#     accuracy                           0.95      1000
#    macro avg       0.91      0.93      0.92      1000
# weighted avg       0.96      0.95      0.95      1000

# %% [markdown]
# BALANCE

# %%
classification_model_performance(randomForest_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(randomForest_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       1.00      1.00      1.00      3360
#
#     accuracy                           1.00      6720
#    macro avg       1.00      1.00      1.00      6720
# weighted avg       1.00      1.00      1.00      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       840
#            1       0.84      0.89      0.86       160
#
#     accuracy                           0.95      1000
#    macro avg       0.91      0.93      0.92      1000
# weighted avg       0.96      0.95      0.95      1000

# %% [markdown]
# # KNN

# %%
from sklearn import set_config
set_config(display=None)

knn
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
knn.get_params()

# %%
knn_gscv = GridSearchCV(estimator=knn,
                          param_grid={
                                 'model__n_neighbors': [1,20]
                          },
                          cv=5,
                          verbose=1)

knn_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('num_imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('num_scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['usia',
#                                                                           'jumlah_tanggungan',
#                                                                           'lama_nasabah',
# ...

# %%
knn_gscv_balanced = knn_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits

# %% [markdown]
# BALANCE

# %%
model_performance(knn_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       1.00      1.00      1.00       640
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91       840
#            1       0.55      0.59      0.57       160
#
#     accuracy                           0.86      1000
#    macro avg       0.74      0.75      0.74      1000
# weighted avg       0.86      0.86      0.86      1000

# %%
classification_model_performance(knn_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(knn_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3360
#            1       1.00      1.00      1.00      3360
#
#     accuracy                           1.00      6720
#    macro avg       1.00      1.00      1.00      6720
# weighted avg       1.00      1.00      1.00      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91       840
#            1       0.55      0.59      0.57       160
#
#     accuracy                           0.86      1000
#    macro avg       0.74      0.75      0.74      1000
# weighted avg       0.86      0.86      0.86      1000

# %% [markdown]
# # Logiscitc Regression

# %%
from sklearn import set_config
set_config(display=None)

LogistRegress
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('num_imputer',
#                                                                    SimpleImputer()),
#                                                                   ('num_scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['usia', 'jumlah_tanggungan',
#                                                    'lama_nasabah',
#                                                    'jumlah_produk',
#                                                    'bulan_nonactive',
#                                                    'jumlah_kontak',
#                                                    'total_limit_kredit',
#                                                    'total_limit_kredit_dipakai',
# ...

# %%
LogistRegress.get_params()

# %%
LogistRegress_gscv = GridSearchCV(estimator=LogistRegress,
                          param_grid={
                               'model__class_weight': ['balanced','dict'],
                               'model__max_iter': [350,500,1000],
                              'model__solver': ['newton-cg','lbfgs','saga'],
                          },
                          cv=5,
                          verbose=1)

LogistRegress_gscv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 45 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1151, in wrapper
# ...

# %%
LogistRegress_gscv_balanced = LogistRegress_gscv.fit(X_train_smotenc,y_train_smotenc)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 45 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1151, in wrapper
# ...

# %%
model_performance(LogistRegress_gscv)
# Out:
# Model Performance on Data Training
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      3360
#            1       0.65      0.69      0.67       640
#
#     accuracy                           0.89      4000
#    macro avg       0.79      0.81      0.80      4000
# weighted avg       0.89      0.89      0.89      4000
#
# Model Performance on Data Testing
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       840
#            1       0.65      0.69      0.67       160
#
#     accuracy                           0.89      1000
#    macro avg       0.79      0.81      0.80      1000
# weighted avg       0.89      0.89      0.89      1000

# %%
classification_model_performance(LogistRegress_gscv_balanced,X_train_smotenc,y_train_smotenc,"Training")
classification_model_performance(LogistRegress_gscv_balanced,x_test,y_test,"Testing")
# Out:
# Model Performance in Data Training
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91      3360
#            1       0.93      0.89      0.91      3360
#
#     accuracy                           0.91      6720
#    macro avg       0.91      0.91      0.91      6720
# weighted avg       0.91      0.91      0.91      6720
#
# Model Performance in Data Testing
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       840
#            1       0.65      0.69      0.67       160
#
#     accuracy                           0.89      1000
#    macro avg       0.79      0.81      0.80      1000
# weighted avg       0.89      0.89      0.89      1000
